# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import numpy as np



img=cv2.imread('circular shape.jpeg')

# plt.imshow(img)
# b,g,r = cv2.split(img)       # get b,g,r
# img = cv2.merge([r,g,b])     # switch it to rgb

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# cv2_imshow(gray)

ret, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# binary=binary/255
print(binary.shape)
cv2_imshow(binary)
cv2.imwrite('binary.jpg',binary)

invert = cv2.bitwise_not(binary)

# contours, hierarchy = cv2.findContours(invert, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)
# image_copy = image.copy()
# image_copy = cv2.drawContours(image_copy, contours, -1, (0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
# # print(invert.shape)
# cv2_imshow(image_copy)
# cv2_imshow(invert)
# cv2.imwrite('invert.jpg',invert)


number_of_black_pix = np.sum(binary == 0)
print(number_of_black_pix)

# resized=cv2.resize(binary,(50,100))
# cv2_imshow(resized)
# Out:
# (213, 223)
# <PIL.Image.Image image mode=L size=223x213 at 0x7F2A1702B130>
# 29207

# %%
# !unzip "/content/threshold_shape_dataset.zip" -d "/content/threshold"
# Out:
# Archive:  /content/threshold_shape_dataset.zip
#   inflating: /content/threshold/threshold_shape_dataset/ROI_0.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_1.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_10.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_100.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_101.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_102.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_103.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_104.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_105.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_11.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_12.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_13.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_14.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_15.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_16.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_17.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_18.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_19.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_2.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_20.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_21.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_22.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_23.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_24.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_25.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_26.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_27.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_28.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_29.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_3.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_30.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_31.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_32.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_33.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_34.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_35.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_36.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_37.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_38.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_39.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_4.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_40.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_41.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_42.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_43.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_44.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_45.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_46.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_47.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_48.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_49.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_5.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_50.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_51.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_52.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_53.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_54.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_55.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_56.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_57.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_58.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_59.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_6.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_60.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_61.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_62.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_63.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_64.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_65.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_66.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_67.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_68.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_69.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_7.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_70.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_71.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_72.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_73.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_74.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_75.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_76.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_77.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_78.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_79.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_8.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_80.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_81.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_82.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_83.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_84.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_85.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_86.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_87.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_88.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_89.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_9.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_90.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_91.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_92.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_93.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_94.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_95.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_96.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_97.png
#   inflating: /content/threshold/threshold_shape_dataset/ROI_98.png
#  extracting: /content/threshold/threshold_shape_dataset/ROI_99.png

# %%
width, height = 1024, 1024  # Specify the dimensions of the image
background_color = (255, 255, 255)  # RGB values for white
image = np.zeros((height, width, 3), dtype=np.uint8)
image[:] = background_color
cv2_imshow(image)
cv2.imwrite('image.jpg',image)
background=cv2.imread('image.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F2A1702B640>

# %%
from PIL import Image

def transparency(image_totrans):

  img = image_totrans
  img=Image.fromarray(image_totrans)
  img = img.convert("RGBA")

  datas = img.getdata()

  # img3=Image.open('back.jpeg')
  # img4=Image.open('actual.png')
  # img4=img4.resize(img3.size)

  newData = []


  for item in datas:





    if item[0] >= 100 and item[1] >= 100 and item[2] >= 100:
      newData.append((255, 255, 255, 0))
    else:
      newData.append(item)


  img.putdata(newData)

  return img

# %%
import cv2
from google.colab.patches import cv2_imshow



def alphaMerge(small_foreground, background, top, left):
    """
    Puts a small BGRA picture in front of a larger BGR background.
    :param small_foreground: The overlay image. Must have 4 channels.
    :param background: The background. Must have 3 channels.
    :param top: Y position where to put the overlay.
    :param left: X position where to put the overlay.
    :return: a copy of the background with the overlay added.
    """
    result = background.copy()
    # From everything I read so far, it seems we need the alpha channel separately
    # so let's split the overlay image into its individual channels
    fg_b, fg_g, fg_r, fg_a = cv2.split(small_foreground)
    # Make the range 0...1 instead of 0...255
    fg_a = fg_a / 255.0
    # Multiply the RGB channels with the alpha channel
    label_rgb = cv2.merge([fg_b * fg_a, fg_g * fg_a, fg_r * fg_a])

    # Work on a part of the background only
    height, width = small_foreground.shape[0], small_foreground.shape[1]
    part_of_bg = result[top:top + height, left:left + width, :]
    # Same procedure as before: split the individual channels
    bg_b, bg_g, bg_r = cv2.split(part_of_bg)
    # Merge them back with opposite of the alpha channel
    part_of_bg = cv2.merge([bg_b * (1 - fg_a), bg_g * (1 - fg_a), bg_r * (1 - fg_a)])

    # Add the label and the part of the background
    cv2.add(label_rgb, part_of_bg, part_of_bg)
    # Replace a part of the background
    result[top:top + height, left:left + width, :] = part_of_bg
    return result

# %%
import imutils
import random

def rotate_image(image,angle):

  invert=cv2.bitwise_not(image)

  rotated = imutils.rotate(invert, angle)
  rotated_invert=cv2.bitwise_not(rotated)

  return rotated_invert

# %%
#Bimodal
import math
import numpy as np
# print(foreground.shape)
mean=50.0
std_dev=10.0

mean2=75.0
std_dev2=10.0
foreground=cv2.imread('circular shape.jpeg')
foreground=cv2.resize(foreground,(62,62))
num_particles = math.ceil((((image.shape[0]*image.shape[1])/(foreground.shape[0]*foreground.shape[1]))+100)/2)
particle_sizes = np.random.normal(mean, std_dev, num_particles)
particle_sizes2=np.random.normal(mean2,std_dev2,num_particles)
particle_sizes=np.append(particle_sizes,particle_sizes2)
particle_sizes=[math.ceil(i) for i in particle_sizes]
print(particle_sizes[190])
print(len(particle_sizes))
# Out:
# 67
# 374

# %%
# # Gaussian
# mean=50.0
# std_dev=10.0

# foreground=cv2.imread('circular shape.jpeg')
# foreground=cv2.resize(foreground,(50,50))
# num_particles=math.ceil((image.shape[0]*image.shape[1]/(foreground.shape[0]*foreground.shape[1])))
# particle_sizes=np.random.normal(mean,std_dev,num_particles)
# particle_sizes=[math.ceil(i) for i in particle_sizes]
# print(particle_sizes[10])
# print(len(particle_sizes))
# Out:
# 47
# 420

# %%
def overlap(result,x0,y0,width):

  flag=0



  for i in range(x0,x0+width):
    for j in range(y0,y0+width):

      if(result[i][j][0]==0 and result[i][j][1]==0 and result[i][j][2]==0):
        flag=1

  return flag

# %%
def inside_circular(x0,y0):
  ans=(x0-512)**2+(y0-512)**2-(300)**2
  return ans

# %%
print(result)
# Out:
# None

# %%
# for i in range(N):
import math
for l in range(2,6):



  i=0
  j=0
  area_fraction=0.06
  foreground=cv2.imread('circular shape.jpeg')

  foreground=cv2.resize(foreground,(50,50))
  print(foreground.shape[0])


  foreground=np.array(foreground)
  foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
  result = alphaMerge(foreground, background, random.randint(0,1024-foreground.shape[0]), random.randint(0,1024-foreground.shape[1]))
  # cv2_imshow(result)
  i+=np.sum(foreground==0)
  while i < area_fraction*(image.shape[0]*image.shape[1]*3):

    foreground=cv2.imread('circular shape.jpeg')
    foreground=cv2.resize(foreground,(62,62))
    x1=random.randint(50,100)
    # print(j)
    # k=random.randint(0,len(particle_sizes)-1)
    foreground=cv2.resize(foreground,(50,50))
    number_of_black_pix = np.sum(foreground ==0)

    x0=random.randint(0,1024-foreground.shape[0])
    y0=random.randint(0,1024-foreground.shape[1])
    if(overlap(result,x0,y0,50)):
      continue
    i+=number_of_black_pix

    angle=random.randint(-180,180)
    foreground=rotate_image(foreground,angle)
    foreground=transparency(foreground)
    foreground=np.array(foreground)
    foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
    j=j+1




    result=alphaMerge(foreground,result,x0,y0)

  # blur = cv2.GaussianBlur(result, (0,0), sigmaX=1.5, sigmaY=1.5, borderType = cv2.BORDER_DEFAULT)
  # ret, binary = cv2.threshold(blur, 127 ,255, cv2.THRESH_BINARY)
  # cv2_imshow(binary)
  # print(binary)
  cv2_imshow(result)

  # result=binary
  cv2.imwrite('result.png',result)
  print(result[12][12][2])
  # print(i)
  # print(j)
  #Distribution Circular
  j=0
  i=0
  area_fraction=0.14

  foreground=cv2.resize(foreground,(50,50))
  foreground=np.array(foreground)
  foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
  x0=random.randint(0,1024-foreground.shape[0])
  y0=random.randint(0,1024-foreground.shape[1])
  while(overlap(result,x0,y0,50)):

    x0=random.randint(0,1024-foreground.shape[0])
    y0=random.randint(0,1024-foreground.shape[1])

  result = alphaMerge(foreground, result, x0, y0)
  i+=np.sum(foreground==0)
  while i < area_fraction*(image.shape[0]*image.shape[1]*3):

    foreground=cv2.imread('circular shape.jpeg')
    foreground=cv2.resize(foreground,(50,50))
    x1=random.randint(50,100)
    # k=random.randint(0,len(particle_sizes)-1)

    foreground=cv2.resize(foreground,(50,50))
    # print(particle_sizes[j])
    number_of_black_pix = np.sum(foreground ==0)

    x0=random.randint(0,1024-foreground.shape[0])
    y0=random.randint(0,1024-foreground.shape[1])

    if(overlap(result,x0,y0,50)):
      continue

    i+=number_of_black_pix
    ans=inside_circular(x0,y0)
    while ans<0:


      x0=random.randint(0,1024-foreground.shape[0])
      y0=random.randint(0,1024-foreground.shape[1])

      if(overlap(result,x0,y0,50)):
        continue
      ans=inside_circular(x0,y0)

    angle=random.randint(-180,180)
    foreground=rotate_image(foreground,angle)
    foreground=transparency(foreground)
    foreground=np.array(foreground)
    foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
    j=j+1




    result=alphaMerge(foreground,result,x0,y0)
  print(j)
  print(i)
  print(area_fraction*image.shape[0]*image.shape[1])
  cv2_imshow(result)
  i=0
  cv2.imwrite('result.png',result)

  print(result.shape)
  print(area_fraction)
  print(np.sum(result<127))
  actual_area_fraction=math.ceil(np.sum(result<127))/(1024*1024*3)
  actual_area_fraction=round(actual_area_fraction,2)
  actual_area_fraction

  # cv2.imwrite(f'circular_bimodal_distributioncircular_{actual_area_fraction}_{l}.png',result)
# Out:
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC1A4730>
# 255
# 110
# 444087
# 146800.64
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC197DC0>
# (1024, 1024, 3)
# 0.14
# 724644
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC1975E0>
# 255
# 110
# 444084
# 146800.64
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC197C40>
# (1024, 1024, 3)
# 0.14
# 724827
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29ECF55A20>
# 255
# 110
# 444078
# 146800.64
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29ECF56860>
# (1024, 1024, 3)
# 0.14
# 724617
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29ECF55870>
# 255
# 110
# 444089
# 146800.64
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29ECF56470>
# (1024, 1024, 3)
# 0.14
# 724671

# %%
# for i in range(N):
import math
import glob
for l in range(2,6):




  i=0
  j=0
  area_fraction=0.07
  # foreground=cv2.imread('circular shape.jpeg')
  foreground_path_list = glob.glob('threshold/threshold_shape_dataset/*.png')
  foreground_image_path = random.choice(foreground_path_list)
  foreground=cv2.imread(foreground_image_path)
  foreground = cv2.cvtColor(foreground, cv2.COLOR_BGR2GRAY)
  foreground=cv2.resize(foreground,(50,50))

  _, thresholded_image = cv2.threshold(foreground, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
  foreground = np.zeros((thresholded_image.shape[0], thresholded_image.shape[1], 3), dtype=np.uint8)
  foreground[:, :, 0] = thresholded_image
  foreground[:, :, 1] = thresholded_image
  foreground[:, :, 2] = thresholded_image

  # foreground=cv2.resize(foreground,(50,50))
  print(foreground.shape[0])


  foreground=np.array(foreground)
  foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
  result = alphaMerge(foreground, background, random.randint(0,1024-foreground.shape[0]), random.randint(0,1024-foreground.shape[1]))
  # cv2_imshow(result)
  i+=np.sum(foreground==0)
  while i < area_fraction*(image.shape[0]*image.shape[1]*3):

    # foreground=cv2.imread('circular shape.jpeg')
    foreground_path_list = glob.glob('threshold/threshold_shape_dataset/*.png')
    foreground_image_path = random.choice(foreground_path_list)
    foreground=cv2.imread(foreground_image_path)
    foreground = cv2.cvtColor(foreground, cv2.COLOR_BGR2GRAY)
    foreground=cv2.resize(foreground,(50,50))

    _, thresholded_image = cv2.threshold(foreground, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    foreground = np.zeros((thresholded_image.shape[0], thresholded_image.shape[1], 3), dtype=np.uint8)
    foreground[:, :, 0] = thresholded_image
    foreground[:, :, 1] = thresholded_image
    foreground[:, :, 2] = thresholded_image
    foreground=cv2.resize(foreground,(50,50))
    x1=random.randint(50,100)
    # print(j)
    k=random.randint(0,len(particle_sizes)-1)
    foreground=cv2.resize(foreground,(particle_sizes[k],particle_sizes[k]))
    number_of_black_pix = np.sum(foreground ==0)

    x0=random.randint(0,1024-foreground.shape[0])
    y0=random.randint(0,1024-foreground.shape[1])
    if(overlap(result,x0,y0,particle_sizes[k])):
      continue
    i+=number_of_black_pix

    angle=random.randint(-180,180)
    foreground=rotate_image(foreground,angle)
    foreground=transparency(foreground)
    foreground=np.array(foreground)
    foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
    j=j+1




    result=alphaMerge(foreground,result,x0,y0)

  # blur = cv2.GaussianBlur(result, (0,0), sigmaX=1.5, sigmaY=1.5, borderType = cv2.BORDER_DEFAULT)
  # ret, binary = cv2.threshold(blur, 127 ,255, cv2.THRESH_BINARY)
  # cv2_imshow(binary)
  # print(binary)
  cv2_imshow(result)

  # # result=binary
  # cv2.imwrite('result.png',result)
  # print(result[12][12][2])
  # # print(i)
  # # print(j)
  #Distribution Circular
  j=0
  i=0
  area_fraction=0.16

  foreground_path_list = glob.glob('threshold/threshold_shape_dataset/*.png')
  foreground_image_path = random.choice(foreground_path_list)
  foreground=cv2.imread(foreground_image_path)
  foreground = cv2.cvtColor(foreground, cv2.COLOR_BGR2GRAY)
  foreground=cv2.resize(foreground,(50,50))

  _, thresholded_image = cv2.threshold(foreground, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
  foreground = np.zeros((thresholded_image.shape[0], thresholded_image.shape[1], 3), dtype=np.uint8)
  foreground[:, :, 0] = thresholded_image
  foreground[:, :, 1] = thresholded_image
  foreground[:, :, 2] = thresholded_image

  # foreground=cv2.resize(foreground,(50,50))
  foreground=np.array(foreground)
  foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
  x0=random.randint(0,1024-foreground.shape[0])
  y0=random.randint(0,1024-foreground.shape[1])
  while(overlap(result,x0,y0,50)):

    x0=random.randint(0,1024-foreground.shape[0])
    y0=random.randint(0,1024-foreground.shape[1])

  result = alphaMerge(foreground, result, x0, y0)
  i+=np.sum(foreground==0)
  while i < area_fraction*(image.shape[0]*image.shape[1]*3):

    # foreground=cv2.imread('circular shape.jpeg')
    foreground_path_list = glob.glob('threshold/threshold_shape_dataset/*.png')
    foreground_image_path = random.choice(foreground_path_list)
    foreground=cv2.imread(foreground_image_path)
    foreground = cv2.cvtColor(foreground, cv2.COLOR_BGR2GRAY)
    foreground=cv2.resize(foreground,(50,50))

    _, thresholded_image = cv2.threshold(foreground, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    foreground = np.zeros((thresholded_image.shape[0], thresholded_image.shape[1], 3), dtype=np.uint8)
    foreground[:, :, 0] = thresholded_image
    foreground[:, :, 1] = thresholded_image
    foreground[:, :, 2] = thresholded_image
    # foreground=cv2.resize(foreground,(50,50))
    x1=random.randint(50,100)
    k=random.randint(0,len(particle_sizes)-1)

    foreground=cv2.resize(foreground,(particle_sizes[k],particle_sizes[k]))
    # print(particle_sizes[j])
    number_of_black_pix = np.sum(foreground ==0)

    x0=random.randint(0,1024-foreground.shape[0])
    y0=random.randint(0,1024-foreground.shape[1])

    if(overlap(result,x0,y0,particle_sizes[k])):
      continue

    i+=number_of_black_pix
    ans=inside_circular(x0,y0)
    while ans<0:


      x0=random.randint(0,1024-foreground.shape[0])
      y0=random.randint(0,1024-foreground.shape[1])

      if(overlap(result,x0,y0,particle_sizes[k])):
        continue
      ans=inside_circular(x0,y0)

    angle=random.randint(-180,180)
    foreground=rotate_image(foreground,angle)
    foreground=transparency(foreground)
    foreground=np.array(foreground)
    foreground=cv2.cvtColor(foreground,cv2.COLOR_RGB2BGRA)
    j=j+1




    result=alphaMerge(foreground,result,x0,y0)
  print(j)
  print(i)
  print(area_fraction*image.shape[0]*image.shape[1])
  cv2_imshow(result)
  i=0
  cv2.imwrite('result.png',result)

  print(result.shape)
  print(area_fraction)
  print(np.sum(result<127))
  actual_area_fraction=math.ceil(np.sum(result<127))/(1024*1024*3)
  actual_area_fraction=round(actual_area_fraction,2)
  actual_area_fraction

  cv2.imwrite(f'irregular_bimodal_distributioncircular_{actual_area_fraction}_{l}.png',result)
# Out:
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC196BF0>
# 78
# 507291
# 167772.16
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC196710>
# (1024, 1024, 3)
# 0.16
# 727233
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC196CE0>
# 79
# 506928
# 167772.16
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC196CE0>
# (1024, 1024, 3)
# 0.16
# 727053
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29E3449C90>
# 77
# 506478
# 167772.16
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29EC196CE0>
# (1024, 1024, 3)
# 0.16
# 735480
# 50
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29E3449480>
# 81
# 504960
# 167772.16
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F29E344BAC0>
# (1024, 1024, 3)
# 0.16
# 723801

# %%
  print(result.shape)
  print(area_fraction)
  print(np.sum(result<127))
  actual_area_fraction=math.ceil(np.sum(result<127))/(1024*1024*3)
  actual_area_fraction=round(actual_area_fraction,2)
  print(actual_area_fraction)

  cv2.imwrite(f'circular_bimodal_distributioncircular_{actual_area_fraction}_{l}.png',result)
# Out:
# (1024, 1024, 3)
# 0.14
# 657195
# 0.21
# True

# %%
print(foreground.shape)
# Out:
# (86, 86, 3)

# %%
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F09D5995060>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-48577bb0aa5c> in <cell line: 10>()
#      33     y0=random.randint(0,1024-foreground.shape[1])
#      34
# ---> 35     if(overlap(result,x0,y0,50)):
#      36       continue
#      37     ans=inside_circular(x0,y0)
#
# <ipython-input-6-b489dc3aedba> in overlap(result, x0, y0, width)
#       1 def overlap(result,x0,y0,width):
#       2
#       3   flag=0
#       4
#       5
#
# KeyboardInterrupt:

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F09D5994AC0>
